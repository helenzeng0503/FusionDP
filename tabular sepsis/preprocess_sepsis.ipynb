# %%
import pandas as pd
import numpy as np

# %%
imputed = pd.read_csv("path to imputed training data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 imputed = pd.read_csv("path to imputed training data")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
acols = ['HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'BaseExcess',
        'HCO3', 'FiO2', 'pH', 'PaCO2', 'SaO2', 'AST', 'BUN', 'Alkalinephos',
        'Calcium', 'Chloride', 'Creatinine', 'Glucose', 'Lactate', 'Magnesium',
        'Phosphate', 'Potassium', 'Bilirubin_total', 'Hct', 'Hgb', 'PTT', 'WBC',
        'Platelets', 'Age', 'Gender', 'Unit1', 'Unit2', 'HospAdmTime', 'ICULOS',
        'SepsisLabel']

# %%
df = imputed
sepsisLabel_1 = df[df['SepsisLabel'] == 1]
num_sepsisLabel_1 = len(sepsisLabel_1)

# Step 2: Calculate how many `sepsisLabel == 0` samples are needed to keep 15% positives
total_samples_needed = num_sepsisLabel_1 / 0.15  # Total samples we want after filtering
num_sepsisLabel_0_needed = total_samples_needed - num_sepsisLabel_1  # Number of `sepsisLabel == 0` samples to keep

# Step 3: Filter `sepsisLabel == 0` and sort by number of missing entries (descending)
sepsisLabel_0 = df[df['SepsisLabel'] == 0]
sepsisLabel_0_random = sepsisLabel_0.sample(n=int(num_sepsisLabel_0_needed), random_state=188)


# Step 5: Combine the indices of `sepsisLabel == 1` and selected `sepsisLabel == 0`
samples_to_keep_indices = list(sepsisLabel_1.index) + list(sepsisLabel_0_random.index)

# Now, samples_to_keep_indices contains the indices of the samples you want to keep
len(samples_to_keep_indices)

# %%
len(sepsisLabel_1.index)

# %%
from sklearn.utils import shuffle

# %%
train_imputed = imputed.loc[samples_to_keep_indices]
train_imputed = shuffle(train_imputed, random_state=42)
# train_imputed

# %%
train_ori = original.loc[samples_to_keep_indices]
train_ori = shuffle(train_ori, random_state=42)
# train_ori

# %%
train_ori.to_csv('path to 15% positive original training data', index=False)
train_imputed.to_csv('path to 15% positive imputed data', index=False)

# %%
val = pd.read_csv("path to validation data")
# val

# %%
df = val
sepsisLabel_1 = df[df['SepsisLabel'] == 1]
num_sepsisLabel_1 = len(sepsisLabel_1)

# Step 2: Calculate how many `sepsisLabel == 0` samples are needed to keep 15% positives
total_samples_needed = num_sepsisLabel_1 / 0.15  # Total samples we want after filtering
num_sepsisLabel_0_needed = total_samples_needed - num_sepsisLabel_1  # Number of `sepsisLabel == 0` samples to keep

# Step 3: Filter `sepsisLabel == 0` and sort by number of missing entries (descending)
sepsisLabel_0 = df[df['SepsisLabel'] == 0]
sepsisLabel_0_random = sepsisLabel_0.sample(n=int(num_sepsisLabel_0_needed), random_state=188)


# Step 5: Combine the indices of `sepsisLabel == 1` and selected `sepsisLabel == 0`
samples_to_keep_indices = list(sepsisLabel_1.index) + list(sepsisLabel_0_random.index)

# Now, samples_to_keep_indices contains the indices of the samples you want to keep
len(samples_to_keep_indices)

# %%
val_15pos = val.loc[samples_to_keep_indices]
val_15pos = shuffle(val_15pos, random_state=42)
# val_15pos

# %%
val_15pos.to_csv('path to 15% positive validation data', index=False)

# %%
test = pd.read_csv("path to test data")
# test

# %%
df = test
sepsisLabel_1 = df[df['SepsisLabel'] == 1]
num_sepsisLabel_1 = len(sepsisLabel_1)

# Step 2: Calculate how many `sepsisLabel == 0` samples are needed to keep 15% positives
total_samples_needed = num_sepsisLabel_1 / 0.15  # Total samples we want after filtering
num_sepsisLabel_0_needed = total_samples_needed - num_sepsisLabel_1  # Number of `sepsisLabel == 0` samples to keep

# Step 3: Filter `sepsisLabel == 0` and sort by number of missing entries (descending)
sepsisLabel_0 = df[df['SepsisLabel'] == 0]
sepsisLabel_0_random = sepsisLabel_0.sample(n=int(num_sepsisLabel_0_needed), random_state=188)


# Step 5: Combine the indices of `sepsisLabel == 1` and selected `sepsisLabel == 0`
samples_to_keep_indices = list(sepsisLabel_1.index) + list(sepsisLabel_0_random.index)

# Now, samples_to_keep_indices contains the indices of the samples you want to keep
len(samples_to_keep_indices)

# %%
test_15pos = test.loc[samples_to_keep_indices]
test_15pos = shuffle(test_15pos, random_state=42)
# test_15pos

# %%
test_15pos.to_csv('path to 15% positive test data', index=False)
